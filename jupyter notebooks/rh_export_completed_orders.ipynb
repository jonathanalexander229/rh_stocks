# %% [markdown]
# This notebook will use the robin_stocks.robinhood.export functions which write all orders to a csv file.  We will do this for stock, options and crypto orders

# %% [markdown]
# This first cell will pull the stock orders using the export_completed_stock_orders function
# https://robin-stocks.readthedocs.io/en/latest/robinhood.html#robin_stocks.robinhood.export.export_completed_stock_orders

# %%
# %pip install robin_stocks pandas numpy ipykernel
# Out:
# Requirement already satisfied: robin_stocks in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: pandas in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: ipykernel in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (6.29.5)
# Requirement already satisfied: requests in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from robin_stocks) (2.32.3)
# Requirement already satisfied: pyotp in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from robin_stocks) (2.9.0)
# Requirement already satisfied: python-dotenv in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from robin_stocks) (1.0.1)
# Requirement already satisfied: cryptography in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from robin_stocks) (43.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: comm>=0.1.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (24.1)
# Requirement already satisfied: psutil in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (26.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack-data in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.2)
# Requirement already satisfied: six>=1.5 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from cryptography->robin_stocks) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from requests->robin_stocks) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from requests->robin_stocks) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from requests->robin_stocks) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from requests->robin_stocks) (2024.7.4)
# Requirement already satisfied: pycparser in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography->robin_stocks) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in /home/clutchcoder/working/rh_stocks/.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This cell logs on to the robinhood web service endpoint

# %%
import robin_stocks.robinhood as r
import pandas as pd

# Prompt for email address
email = input("Please enter your Robinhood email address: ")

login = r.login(email)

# %% [markdown]
# Now that we are logged in lets get all the stock orders

# %%
# # Get all stock orders
r.export_completed_stock_orders('/', file_name='../output/stock_output.csv')
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...

# %% [markdown]
# Now that we have the stock orders lets parse them, caclute cost of each order, and sum up the total for cumulative stock profit and loss.  Stock buys will be updated with a negative cost and sells will be a positive cost.   For example I buy 10 shares of AMD for $10 a share, this will cost me $100 and will reduce my balance by that much.  Then if I decide to sell my 10 AMD shares and get filled at $11 share for a total of $110, which will be added to my balance.  The total P&L for that trade would be +$10 since I sold the position for $10 more than I paid for it.  Conversly if I sold the 10 AMD and got filled at $9 a share for a total of $90, which will be added back to my cash balance.  The total P&L for this trade would be -$10 since I sold the position for $10 less than I paid for it.

# %%
import pandas as pd

# Load your spreadsheet
df = pd.read_csv('../output/stock_output.csv')

# Convert the 'date' column to datetime
df['date'] = pd.to_datetime(df['date'],  errors='coerce', utc=True)

#df = df[df['date'] >= '2019-02-12']

# Sort the DataFrame based on the date column
df = df.sort_values(by=['symbol','date'])

# Assuming 'quantity', 'average_price', and 'type' columns exist
df['cost'] = df['quantity'] * df['average_price']

# Adjust the cost based on the type of order
df.loc[df['side'] == 'buy', 'cost'] *= -1

print(df)
total_stock_cost = df['cost'].sum()
print(total_stock_cost)

df.to_csv('../output/processed_stock_orders.csv', index=False)
# Out:
#     symbol                             date order_type  side  fees  quantity  \
# 390   AAPL 2017-04-04 18:41:43.529000+00:00     market   buy  0.00       1.0
# 372   AAPL 2017-04-10 15:43:06.897000+00:00     market  sell  0.02       1.0
# 280   AAPL 2017-11-06 15:30:09.183000+00:00     market   buy  0.00       1.0
# 268   AAPL 2017-11-13 16:03:16.685000+00:00     market   buy  0.00       1.0
# 266   AAPL 2017-11-13 19:06:33.486000+00:00     market   buy  0.00       1.0
# ..     ...                              ...        ...   ...   ...       ...
# 364    XOP 2017-04-11 13:30:00.553000+00:00     market  sell  0.02       2.0
# 282    XOP 2017-11-01 17:42:02.880000+00:00      limit   buy  0.00       1.0
# 277    XOP 2017-11-06 17:31:33.778000+00:00     market  sell  0.02       1.0
# 241    XSD 2017-11-27 14:57:07.327000+00:00     market   buy  0.00       2.0
# 234    XSD 2017-11-28 15:47:24.601000+00:00     market  sell  0.02       2.0
#
#      average_price    cost
# 390         144.77 -144.77
# 372         143.24  143.24
# 280         173.68 -173.68
# 268         174.12 -174.12
# 266         174.33 -174.33
# ..             ...     ...
# 364          37.84   75.68
# 282          35.12  -35.12
# 277          36.48   36.48
# 241          73.98 -147.96
# 234          73.57  147.14
#
# [465 rows x 8 columns]
# 3296.7660999999985

# %% [markdown]
# Now lets get all crypto orders

# %%
# # Get all crypto orders
r.export_completed_crypto_orders('/', file_name='../output/crypto_output.csv')

# %% [markdown]
# Now lets do the same thing we did with the stock orders to the crypto orders

# %%
import pandas as pd

# Load your spreadsheet
df = pd.read_csv('../output/crypto_output.csv')

# Convert the 'date' column to datetime
df['date'] = pd.to_datetime(df['date'],  errors='coerce', utc=True)

#df = df[df['date'] >= '2019-02-12']

# Sort the DataFrame based on the date column
df = df.sort_values(by=['symbol','date'])

# Assuming 'quantity', 'average_price', and 'type' columns exist
df['cost'] = df['quantity'] * df['average_price']

# Adjust the cost based on the type of order
df.loc[df['side'] == 'buy', 'cost'] *= -1

print(df)
total_crypto_cost = df['cost'].sum()
print(total_crypto_cost)

df.to_csv('../output/processed_crypto_orders.csv', index=False)
# Out:
#      symbol                             date order_type  side  fees  \
# 22   BTCUSD 2018-08-05 06:49:50.771000+00:00     market   buy   0.0
# 21   BTCUSD 2018-08-12 07:49:48.270000+00:00     market  sell   0.0
# 9    BTCUSD 2023-12-14 15:06:24.232000+00:00     market  sell   0.0
# 8    BTCUSD 2024-06-24 19:04:34.507719+00:00     market   buy   0.0
# 7    BTCUSD 2024-07-04 14:30:08.042036+00:00     market   buy   0.0
# 6    BTCUSD 2024-07-05 02:53:50.275000+00:00      limit   buy   0.0
# 3    BTCUSD 2024-08-12 23:20:08.899000+00:00     market  sell   0.0
# 15  DOGEUSD 2018-09-09 02:23:25.038000+00:00     market   buy   0.0
# 14  DOGEUSD 2018-09-10 16:45:36.039000+00:00     market  sell   0.0
# 11  DOGEUSD 2018-10-09 11:18:51.460000+00:00     market   buy   0.0
# 10  DOGEUSD 2018-10-09 11:19:30.680000+00:00     market  sell   0.0
# 34   ETHUSD 2018-06-06 20:23:57.487000+00:00      limit   buy   0.0
# 33   ETHUSD 2018-06-29 20:23:59.053000+00:00      limit   buy   0.0
# 32   ETHUSD 2018-06-29 23:11:44.353000+00:00      limit  sell   0.0
# 31   ETHUSD 2018-06-29 23:18:56.553000+00:00      limit   buy   0.0
# 30   ETHUSD 2018-07-02 19:47:49.854000+00:00      limit   buy   0.0
# 29   ETHUSD 2018-07-03 04:36:41.294000+00:00     market   buy   0.0
# 28   ETHUSD 2018-07-05 05:17:37.495000+00:00      limit   buy   0.0
# 27   ETHUSD 2018-07-08 02:11:51.893000+00:00     market  sell   0.0
# 26   ETHUSD 2018-07-10 21:17:30.079000+00:00      limit   buy   0.0
# 25   ETHUSD 2018-07-17 05:56:19.536000+00:00     market  sell   0.0
# 24   ETHUSD 2018-07-27 19:25:13.529000+00:00      limit   buy   0.0
# 23   ETHUSD 2018-08-05 06:49:04.018000+00:00     market   buy   0.0
# 20   ETHUSD 2018-08-12 07:50:38.976000+00:00      limit   buy   0.0
# 19   ETHUSD 2018-08-15 16:29:42.145000+00:00     market   buy   0.0
# 18   ETHUSD 2018-08-15 17:01:41.929000+00:00      limit   buy   0.0
# 17   ETHUSD 2018-08-15 22:05:42.746000+00:00     market  sell   0.0
# 16   ETHUSD 2018-09-08 02:37:14.736000+00:00     market   buy   0.0
# 13   ETHUSD 2018-09-16 10:24:31.143000+00:00     market   buy   0.0
# 12   ETHUSD 2018-10-05 14:17:23.669000+00:00     market  sell   0.0
# 5    ETHUSD 2024-07-08 11:15:56.418578+00:00     market   buy   0.0
# 4    ETHUSD 2024-07-21 18:36:39.431567+00:00     market   buy   0.0
# 2    ETHUSD 2024-08-12 23:20:29.634000+00:00     market   buy   0.0
# 1    ETHUSD 2024-08-19 17:56:39.479000+00:00     market  sell   0.0
# 0    ETHUSD 2024-08-19 19:01:44.782000+00:00     market  sell   0.0
#
#        quantity  average_price         cost
# 22     0.004579    6987.690000   -31.999987
# 21     0.004579    6321.940000    28.951198
# 9      0.000024   42511.330000     1.029624
# 8      0.000500   60608.398351   -30.304199
# 7      0.001747   57220.160459   -99.978498
# 6      0.001757   56845.167682   -99.903108
# 3      0.004005   59396.110000   237.870729
# 15  7819.000000       0.005755   -44.998345
# 14  7819.000000       0.006317    49.392623
# 11  1421.000000       0.005629    -7.998809
# 10  1421.000000       0.005557     7.896497
# 34     0.372106     596.350000  -221.905413
# 33     1.324056     414.210000  -548.437236
# 32     1.696162     432.800000   734.098914
# 31     1.684114     437.840000  -737.372474
# 30     0.017238     477.950000    -8.238902
# 29     0.309099     485.280000  -149.999563
# 28     0.019064     474.180000    -9.039768
# 27     2.029515     482.220000   978.672723
# 26     2.547787     443.000000 -1128.669641
# 25     2.547787     471.270000  1200.695579
# 24     0.024702     469.190000   -11.589931
# 23     1.001032     406.800000  -407.219818
# 20     0.091145     326.320000   -29.742436
# 19     0.997646     301.700000  -300.989798
# 18     0.063407     304.950000   -19.335965
# 17     1.135074     290.730000   330.000064
# 16     1.002186     219.520000  -219.999871
# 13     0.091203     219.290000   -19.999906
# 12     2.136247     221.480000   473.135986
# 5      0.065455    3054.616529  -199.939925
# 4      0.028648    3489.673250   -99.972159
# 2      0.072434    2761.040762  -199.993227
# 1      0.057809    2594.905740   150.008906
# 0      0.108728    2594.100264   282.051334
# -153.82480036979769

# %% [markdown]
# Now lets get all the options orders.

# %%
# # Get all option orders
r.export_completed_option_orders('/', file_name='../output/options_output.csv')
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...

# %% [markdown]
# This groups spread order by order_created_at and then calculates total cost based on debit and credit direction.  Spreads orders show up multiple time (number of legs) with the total price and quantity listed on each order, so we group them and only sum them up once per opening and closing spread order

# %%
import pandas as pd

# Load your spreadsheet
df = pd.read_csv('../output/options_output.csv')

# Convert 'order_created_at' to datetime
df['order_created_at'] = pd.to_datetime(df['order_created_at'])
df['order_created_at'] = df['order_created_at'].dt.strftime('%Y-%m-%d %H:%M:%S')

# Filter for the year 2024
#df = df[df['order_created_at'].str.startswith('2024')]

# Select only the columns we want
df = df[['order_created_at', 'chain_symbol', 'expiration_date', 
         'strike_price', 'option_type', 'direction', 'order_quantity', 
         'order_type', 'opening_strategy', 'closing_strategy', 'price', 'processed_quantity']]

# Group by 'order_created_at' and aggregate
aggregated_df = df.groupby('order_created_at').agg({
    'chain_symbol': 'first',
    'expiration_date': 'first',
    'strike_price': lambda x: list(sorted(x, key=abs, reverse=True)),  # Create a list of strike price
    'option_type': 'first',
    'direction': 'first',
    'opening_strategy': 'first',
    'closing_strategy': 'first',
    'price': 'first',
    'order_quantity': 'first'
}).reset_index()

# Sort the DataFrame
aggregated_df = aggregated_df.sort_values(by=['chain_symbol', 'expiration_date'])

# Calculate cost
aggregated_df['cost'] = aggregated_df['price'] * aggregated_df['order_quantity'] * 100

# Adjust the cost based on the direction
aggregated_df['cost'] = aggregated_df.apply(
    lambda x: -x['cost'] if x['direction'] == 'debit' else x['cost'],
    axis=1
)      

total_option_cost = aggregated_df['cost'].sum()
print(f"Total option cost: ${total_option_cost:.2f}")
print(aggregated_df['order_created_at'].count())
print(aggregated_df['order_quantity'].sum())

# Save the results
aggregated_df.to_csv('../output/options_orders_parsed.csv', index=False)

# Count rows where 'opening_strategy' is not None
total_opening_strategy_count = aggregated_df['opening_strategy'].notna().sum()
total_closing_strategy_count = aggregated_df['closing_strategy'].notna().sum()


# # Count rows where 'closing_strategy' contains 'spread' or 'iron'
# spread_closing_count = df['closing_strategy'].str.contains('spread|iron', case=False, na=False).sum()

# # Count rows where 'opening_strategy' contains 'spread' or 'iron'
# spread_opening_count = df['opening_strategy'].str.contains('spread|iron', case=False, na=False).sum()

# # Count rows where 'closing_strategy' contains 'spread' or 'iron'
# non_spread_closing_count = total_closing_strategy_count - spread_closing_count

# # Count rows where 'opening_strategy' contains 'spread' or 'iron'
# non_spread_opening_count = total_opening_strategy_count - spread_opening_count
# Calculate total order quantity for opening_strategy
total_opening_quantity = aggregated_df['order_quantity'][aggregated_df['opening_strategy'].notna()].sum()
print(f"Total opening strategy quantity: {total_opening_quantity}")

# Calculate total order quantity for closing_strategy
total_closing_quantity = aggregated_df['order_quantity'][aggregated_df['closing_strategy'].notna()].sum()
print(f"Total closing strategy quantity: {total_closing_quantity}")


#Print the counts
print(f"Opening strategy rows: {total_opening_strategy_count}")
print(f"Closing strategy rows: {total_closing_strategy_count}")
# print(f"Opening strategy rows with 'spread' or 'iron': {spread_opening_count}")
# print(f"Closing strategy rows with 'spread' or 'iron': {spread_closing_count}")
# print(f"Opening strategy rows not with 'spread' or 'iron': {non_spread_opening_count}")
# print(f"Closing strategy rows not with 'spread' or 'iron': {non_spread_closing_count}")
# Out:
# Total option cost: $-3339.00
# 865
# 1607.0
# Total opening strategy quantity: 1001.0
# Total closing strategy quantity: 607.0
# Opening strategy rows: 540
# Closing strategy rows: 326

# %% [markdown]
# # AAPL Spread Order Analysis
#
# This cell analyzes AAPL spread orders by:
#
# 1. Filtering for AAPL spread/iron condor orders
# 2. Pairing opening orders with corresponding closing orders
# 3. Handling partial closings and multiple closing orders per opening order
# 4. Calculating total opened and closed quantities
# 5. Identifying unpaired (still open) orders
#
# The analysis provides:
# - Count of paired and unpaired orders
# - Detailed view of first few paired orders (open and close details)
# - List of unpaired (open) orders
# - Summary of total opened, closed, and remaining open quantities
#
# This helps in understanding the current state of AAPL spread positions, including fully closed, partially closed, and still open trades.

# %%
# Assuming we're using the aggregated_df from the previous cell

# Filter for AAPL spread orders
aapl_spreads = aggregated_df[
    (aggregated_df['chain_symbol'] == 'AAPL') & 
    (aggregated_df['opening_strategy'].str.contains('spread|iron', case=False, na=False) | 
     aggregated_df['closing_strategy'].str.contains('spread|iron', case=False, na=False))
]

# Sort by expiration date and strike price
aapl_spreads = aapl_spreads.sort_values(['expiration_date', 'strike_price'])

# Initialize lists to store paired and unpaired orders
paired_orders = []
unpaired_opens = []

# Iterate through the orders
for _, order in aapl_spreads.iterrows():
    if pd.notna(order['opening_strategy']):
        # This is an opening order
        remaining_quantity = order['processed_quantity']
        matching_closes = []

        potential_closes = aapl_spreads[
            (aapl_spreads['closing_strategy'].notna()) &
            (aapl_spreads['expiration_date'] == order['expiration_date']) &
            (aapl_spreads['strike_price'] == order['strike_price']) &
            (aapl_spreads['option_type'] == order['option_type'])
        ]

        for _, close_order in potential_closes.iterrows():
            if remaining_quantity > 0:
                matched_quantity = min(remaining_quantity, close_order['processed_quantity'])
                matching_closes.append((close_order, matched_quantity))
                remaining_quantity -= matched_quantity

        if matching_closes:
            paired_orders.append((order, matching_closes))
            for close_order, _ in matching_closes:
                aapl_spreads = aapl_spreads[aapl_spreads.index != close_order.name]
        else:
            unpaired_opens.append(order)

    aapl_spreads = aapl_spreads[aapl_spreads.index != order.name]

# Print results
print(f"Paired orders: {len(paired_orders)}")
print(f"Unpaired opening orders: {len(unpaired_opens)}")

# Display first few paired orders
for i, (open_order, close_orders) in enumerate(paired_orders[:5]):
    print(f"\nPair {i+1}:")
    print(f"Open: {open_order['order_created_at']} - {open_order['strike_price']} - {open_order['opening_strategy']} - Quantity: {open_order['processed_quantity']}")
    total_closed = sum(close_order[1] for close_order in close_orders)
    print(f"Closed: {total_closed} out of {open_order['processed_quantity']}")
    for j, (close_order, matched_quantity) in enumerate(close_orders):
        print(f"  Close {j+1}: {close_order['order_created_at']} - {close_order['strike_price']} - {close_order['closing_strategy']} - Matched Quantity: {matched_quantity}")

# Display unpaired opening orders
print("\nUnpaired opening orders:")
for i, order in enumerate(unpaired_opens[:5]):
    print(f"{i+1}: {order['order_created_at']} - Exp: {order['expiration_date']} - {order['strike_price']} - {order['opening_strategy']} - Quantity: {order['processed_quantity']}")

# Calculate total opened and closed quantities
total_opened = sum(order['processed_quantity'] for order, _ in paired_orders) + sum(order['processed_quantity'] for order in unpaired_opens)
total_closed = sum(sum(close_order[1] for close_order in close_orders) for _, close_orders in paired_orders)

print(f"\nTotal opened quantity: {total_opened}")
print(f"Total closed quantity: {total_closed}")
print(f"Remaining open quantity: {total_opened - total_closed}")
# Out:
# Paired orders: 5
# Unpaired opening orders: 1
#
# Pair 1:
# Open: 2023-12-19 15:59:35.91 - 202.5/202.5 - call_calendar_spread - Quantity: 1.0
# Closed: 1.0 out of 1.0
#   Close 1: 2023-12-22 18:58:08.92 - 202.5/202.5 - call_calendar_spread - Matched Quantity: 1.0
#
# Pair 2:
# Open: 2024-03-05 14:38:28.74 - 170.0/167.5 - short_put_spread - Quantity: 2.0
# Closed: 2.0 out of 2.0
#   Close 1: 2024-03-11 14:37:40.33 - 170.0/167.5 - short_put_spread - Matched Quantity: 2.0
#
# Pair 3:
# Open: 2024-03-21 15:13:48.01 - 172.5/170.0 - short_put_spread - Quantity: 4.0
# Closed: 4.0 out of 4.0
#   Close 1: 2024-03-21 17:33:25.67 - 172.5/170.0 - short_put_spread - Matched Quantity: 4.0
#
# Pair 4:
# Open: 2024-04-16 14:29:41.45 - 172.5/170.0 - short_call_spread - Quantity: 3.0
# Closed: 3.0 out of 3.0
#   Close 1: 2024-04-18 13:31:39.85 - 172.5/170.0 - short_call_spread - Matched Quantity: 3.0
#
# Pair 5:
# Open: 2024-05-16 14:59:20.30 - 192.5/190.0 - long_call_spread - Quantity: 1.0
# Closed: 1.0 out of 1.0
#   Close 1: 2024-05-17 18:37:35.54 - 192.5/190.0 - long_call_spread - Matched Quantity: 1.0
#
# Unpaired opening orders:
# 1: 2019-04-23 15:32:43.12 - Exp: 2019-05-03 - 205.0/202.5 - short_put_spread - Quantity: 2.0
#
# Total opened quantity: 13.0
# Total closed quantity: 11.0
# Remaining open quantity: 2.0

# %% [markdown]
# # AAPL Spread Order Analysis
#
# This cell analyzes AAPL spread orders by:
#
# 1. Filtering for AAPL spread/iron condor orders
# 2. Pairing opening orders with corresponding closing orders
# 3. Handling partial closings and multiple closing orders per opening order
# 4. Calculating total opened and closed quantities
# 5. Identifying unpaired (still open) orders
#
# The analysis provides:
# - Count of paired and unpaired orders
# - Detailed view of first few paired orders (open and close details)
# - List of unpaired (open) orders
# - Summary of total opened, closed, and remaining open quantities
#
# For unpaired opening orders, it searches for potential closing orders of individual legs by matching:
# - Expiration date
# - Any matching strike price
# - AAPL as the underlying
#
# This helps in understanding the current state of AAPL spread positions, including fully closed, partially closed, and still open trades, as well as identifying potential leg-by-leg closures.

# %%
# Assuming we're using the aggregated_df and aapl_spreads from the previous cell

# Convert strike_price to float when creating aggregated_df
aggregated_df = df.groupby('order_created_at').agg({
    'chain_symbol': 'first',
    'expiration_date': 'first',
    'strike_price': lambda x: [float(s) for s in sorted(x, key=abs, reverse=True)],
    'option_type': 'first',
    'direction': 'first',
    'order_quantity': 'first',
    'order_type': 'first',
    'opening_strategy': 'first',
    'closing_strategy': 'first',
    'price': 'first',
    'processed_quantity': 'first'
}).reset_index()

# Function to extract strike prices from the strike_price string
def extract_strikes(strike_string):
    return [float(s.strip('+-')) for s in strike_string.split('/')]

# Process unpaired opening orders
for i, open_order in enumerate(unpaired_opens):
    print(f"\nAnalyzing unpaired order {i+1}:")
    print(f"Open: {open_order['order_created_at']} - Exp: {open_order['expiration_date']} - {open_order['strike_price']} - {open_order['opening_strategy']} - Quantity: {open_order['processed_quantity']}")
    
    strikes = extract_strikes(open_order['strike_price'])
    
    potential_closes = aggregated_df[
        (aggregated_df['closing_strategy'].notna()) &
        (aggregated_df['expiration_date'] == open_order['expiration_date']) &
        (aggregated_df['chain_symbol'] == 'AAPL') &
        (aggregated_df['strike_price'].apply(lambda x: any(s in strikes for s in x)))
    ]
    
    if not potential_closes.empty:
        print("Potential closing orders for individual legs:")
        for _, close in potential_closes.iterrows():
            print(f"  Close: {close['order_created_at']} - Exp: {close['expiration_date']} - {close['strike_price']} - {close['closing_strategy']} - Quantity: {close['processed_quantity']}")
    else:
        print("No potential closing orders found for individual legs.")

# Calculate and print summary
total_unpaired_quantity = sum(order['processed_quantity'] for order in unpaired_opens)
print(f"\nTotal quantity of unpaired opening orders: {total_unpaired_quantity}")
print(f"Number of unpaired opening orders: {len(unpaired_opens)}")
# Out:
# Analyzing unpaired order 1:
# Open: 2019-04-23 15:32:43.12 - Exp: 2019-05-03 - 205.0/202.5 - short_put_spread - Quantity: 2.0
# Potential closing orders for individual legs:
#   Close: 2019-04-24 19:12:28.83 - Exp: 2019-05-03 - [205.0] - short_put - Quantity: 2.0
#   Close: 2019-04-24 19:12:53.83 - Exp: 2019-05-03 - [202.5] - long_put - Quantity: 2.0
#
# Total quantity of unpaired opening orders: 2.0
# Number of unpaired opening orders: 1

# %%
# Get all unique chain symbols
unique_symbols = aggregated_df['chain_symbol'].unique()

# Function to extract strike prices from the strike_price string
def extract_strikes(strike_string):
    return [float(s.strip('+-')) for s in strike_string.split('/')]

# Analyze each symbol
for symbol in unique_symbols:
    print(f"\n--- Analysis for {symbol} ---")
    
    # Filter for the current symbol's spread orders
    symbol_spreads = aggregated_df[
        (aggregated_df['chain_symbol'] == symbol) & 
        (aggregated_df['opening_strategy'].str.contains('spread|iron', case=False, na=False))
    ]
    
    # Find unpaired opening orders
    unpaired_opens = []
    for _, order in symbol_spreads.iterrows():
        closing_order = aggregated_df[
            (aggregated_df['chain_symbol'] == symbol) &
            (aggregated_df['closing_strategy'].str.contains('spread|iron', case=False, na=False)) &
            (aggregated_df['expiration_date'] == order['expiration_date']) &
            (aggregated_df['strike_price'] == order['strike_price'])
        ]
        if closing_order.empty:
            unpaired_opens.append(order)

    # Process unpaired opening orders
    for i, open_order in enumerate(unpaired_opens):
        print(f"\nAnalyzing unpaired order {i+1}:")
        print(f"Open: {open_order['order_created_at']} - Exp: {open_order['expiration_date']} - {open_order['strike_price']} - {open_order['opening_strategy']} - Quantity: {open_order['processed_quantity']}")
        
        strikes = set(open_order['strike_price'])
        
        potential_closes = aggregated_df[
            (aggregated_df['closing_strategy'].notna()) &
            (aggregated_df['expiration_date'] == open_order['expiration_date']) &
            (aggregated_df['chain_symbol'] == symbol) &
            (aggregated_df['strike_price'].apply(lambda x: any(s in strikes for s in x)))
        ]
        
        if not potential_closes.empty:
            print("Potential closing orders for individual legs:")
            for _, close in potential_closes.iterrows():
                print(f"  Close: {close['order_created_at']} - Exp: {close['expiration_date']} - {close['strike_price']} - {close['closing_strategy']} - Quantity: {close['processed_quantity']}")
        else:
            print("No potential closing orders found for individual legs.")

    # Calculate and print summary for this symbol
    total_unpaired_quantity = sum(order['processed_quantity'] for order in unpaired_opens)
    print(f"\nTotal quantity of unpaired opening orders for {symbol}: {total_unpaired_quantity}")
    print(f"Number of unpaired opening orders for {symbol}: {len(unpaired_opens)}")
# Out:
# --- Analysis for AAPL ---
#
# Analyzing unpaired order 1:
# Open: 2019-04-23 15:32:43.12 - Exp: 2019-05-03 - 205.0/202.5 - short_put_spread - Quantity: 2.0
# Potential closing orders for individual legs:
#   Close: 2019-04-24 19:12:53.83 - Exp: 2019-05-03 - 202.5 - long_put - Quantity: 2.0
#   Close: 2019-04-24 19:12:28.83 - Exp: 2019-05-03 - 205.0 - short_put - Quantity: 2.0
#
# Total quantity of unpaired opening orders for AAPL: 2.0
# Number of unpaired opening orders for AAPL: 1
#
# --- Analysis for ACB ---
#
# Total quantity of unpaired opening orders for ACB: 0
# Number of unpaired opening orders for ACB: 0
#
# --- Analysis for ADI ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-21 17:20:09.33 - Exp: 2023-12-29 - 197.5/197.5 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for ADI: 1.0
# Number of unpaired opening orders for ADI: 1
#
# --- Analysis for AI ---
#
# Total quantity of unpaired opening orders for AI: 0
# Number of unpaired opening orders for AI: 0
#
# --- Analysis for ALK ---
#
# Total quantity of unpaired opening orders for ALK: 0
# Number of unpaired opening orders for ALK: 0
#
# --- Analysis for AMAT ---
#
# Total quantity of unpaired opening orders for AMAT: 0
# Number of unpaired opening orders for AMAT: 0
#
# --- Analysis for AMC ---
#
# Total quantity of unpaired opening orders for AMC: 0
# Number of unpaired opening orders for AMC: 0
#
# --- Analysis for AMD ---
#
# Analyzing unpaired order 1:
# Open: 2019-04-22 14:05:57.47 - Exp: 2019-10-18 - 39.0/36.0/20.0/17.0 - iron_condor - Quantity: 5.0
# Potential closing orders for individual legs:
#   Close: 2019-04-26 17:22:55.72 - Exp: 2019-10-18 - 17.0 - long_put - Quantity: 4.0
#   Close: 2019-04-26 17:15:54.82 - Exp: 2019-10-18 - 20.0 - short_put - Quantity: 4.0
#   Close: 2019-04-24 19:18:04.84 - Exp: 2019-10-18 - 36.0 - short_call - Quantity: 4.0
#   Close: 2019-04-24 19:18:47.40 - Exp: 2019-10-18 - 39.0 - long_call - Quantity: 4.0
#
# Analyzing unpaired order 2:
# Open: 2023-12-12 14:44:18.09 - Exp: 2023-12-15 - 133.0/133.0 - call_calendar_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2023-12-07 19:34:25.27 - Exp: 2023-12-15 - 127.0 - long_call - Quantity: 1.0
#   Close: 2023-12-07 17:23:36.81 - Exp: 2023-12-15 - 128.0 - long_call - Quantity: 1.0
#   Close: 2023-12-12 15:08:10.38 - Exp: 2023-12-15 - 135.0 - long_call - Quantity: 1.0
#   Close: 2023-12-07 16:39:19.60 - Exp: 2023-12-15 - 137.0 - long_call - Quantity: 1.0
#
# Analyzing unpaired order 3:
# Open: 2023-12-18 18:07:24.47 - Exp: 2023-12-22 - 139.0/139.0 - call_calendar_spread - Quantity: 2.0
# Potential closing orders for individual legs:
#   Close: 2023-12-14 14:42:19.08 - Exp: 2023-12-22 - 133.0/133.0 - call_calendar_spread - Quantity: 1.0
#   Close: 2023-12-19 14:41:10.66 - Exp: 2023-12-22 - 140.0 - long_call - Quantity: 1.0
#   Close: 2023-12-21 16:48:02.41 - Exp: 2023-12-22 - 142.0 - long_call - Quantity: 1.0
#   Close: 2023-12-19 14:42:28.14 - Exp: 2023-12-22 - 145.0 - long_call - Quantity: 1.0
#
# Analyzing unpaired order 4:
# Open: 2023-12-26 16:40:56.36 - Exp: 2023-12-29 - 142.0/142.0 - call_calendar_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2023-12-22 18:55:44.26 - Exp: 2023-12-29 - 139.0/139.0 - call_calendar_spread - Quantity: 1.0
#   Close: 2023-12-22 18:57:02.51 - Exp: 2023-12-29 - 139.0/139.0 - call_calendar_spread - Quantity: 1.0
#   Close: 2023-12-29 20:30:55.63 - Exp: 2023-12-29 - 142.0 - short_call - Quantity: 1.0
#   Close: 2023-12-28 14:31:14.24 - Exp: 2023-12-29 - 145.0 - long_call - Quantity: 1.0
#
# Analyzing unpaired order 5:
# Open: 2024-02-02 16:32:15.71 - Exp: 2024-02-09 - 192.5/187.5 - long_call_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2024-02-07 14:33:45.59 - Exp: 2024-02-09 - 165.0 - long_put - Quantity: 1.0
#
# Analyzing unpaired order 6:
# Open: 2024-08-19 17:58:41.57 - Exp: 2024-08-23 - 150.0/148.0 - short_put_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for AMD: 11.0
# Number of unpaired opening orders for AMD: 6
#
# --- Analysis for AMRS ---
#
# Total quantity of unpaired opening orders for AMRS: 0
# Number of unpaired opening orders for AMRS: 0
#
# --- Analysis for AMZN ---
#
# Total quantity of unpaired opening orders for AMZN: 0
# Number of unpaired opening orders for AMZN: 0
#
# --- Analysis for ANET ---
#
# Total quantity of unpaired opening orders for ANET: 0
# Number of unpaired opening orders for ANET: 0
#
# --- Analysis for ARM ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-12 15:15:50.30 - Exp: 2023-12-15 - 65.0/65.0 - call_calendar_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2023-12-14 15:05:26.46 - Exp: 2023-12-15 - 70.0 - long_call - Quantity: 1.0
#
# Total quantity of unpaired opening orders for ARM: 1.0
# Number of unpaired opening orders for ARM: 1
#
# --- Analysis for AVGO ---
#
# Total quantity of unpaired opening orders for AVGO: 0
# Number of unpaired opening orders for AVGO: 0
#
# --- Analysis for BA ---
#
# Total quantity of unpaired opening orders for BA: 0
# Number of unpaired opening orders for BA: 0
#
# --- Analysis for BB ---
#
# Total quantity of unpaired opening orders for BB: 0
# Number of unpaired opening orders for BB: 0
#
# --- Analysis for BOX ---
#
# Total quantity of unpaired opening orders for BOX: 0
# Number of unpaired opening orders for BOX: 0
#
# --- Analysis for BYND ---
#
# Total quantity of unpaired opening orders for BYND: 0
# Number of unpaired opening orders for BYND: 0
#
# --- Analysis for CAT ---
#
# Total quantity of unpaired opening orders for CAT: 0
# Number of unpaired opening orders for CAT: 0
#
# --- Analysis for CMCSA ---
#
# Total quantity of unpaired opening orders for CMCSA: 0
# Number of unpaired opening orders for CMCSA: 0
#
# --- Analysis for COIN ---
#
# Total quantity of unpaired opening orders for COIN: 0
# Number of unpaired opening orders for COIN: 0
#
# --- Analysis for CSCO ---
#
# Total quantity of unpaired opening orders for CSCO: 0
# Number of unpaired opening orders for CSCO: 0
#
# --- Analysis for DIS ---
#
# Total quantity of unpaired opening orders for DIS: 0
# Number of unpaired opening orders for DIS: 0
#
# --- Analysis for DJT ---
#
# Total quantity of unpaired opening orders for DJT: 0
# Number of unpaired opening orders for DJT: 0
#
# --- Analysis for DOCU ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-15 18:53:01.10 - Exp: 2023-12-22 - 62.0/62.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for DOCU: 1.0
# Number of unpaired opening orders for DOCU: 1
#
# --- Analysis for F ---
#
# Total quantity of unpaired opening orders for F: 0
# Number of unpaired opening orders for F: 0
#
# --- Analysis for FB ---
#
# Total quantity of unpaired opening orders for FB: 0
# Number of unpaired opening orders for FB: 0
#
# --- Analysis for GDX ---
#
# Total quantity of unpaired opening orders for GDX: 0
# Number of unpaired opening orders for GDX: 0
#
# --- Analysis for GDXJ ---
#
# Total quantity of unpaired opening orders for GDXJ: 0
# Number of unpaired opening orders for GDXJ: 0
#
# --- Analysis for GIL ---
#
# Total quantity of unpaired opening orders for GIL: 0
# Number of unpaired opening orders for GIL: 0
#
# --- Analysis for GLD ---
#
# Total quantity of unpaired opening orders for GLD: 0
# Number of unpaired opening orders for GLD: 0
#
# --- Analysis for GOOGL ---
#
# Total quantity of unpaired opening orders for GOOGL: 0
# Number of unpaired opening orders for GOOGL: 0
#
# --- Analysis for GPRO ---
#
# Total quantity of unpaired opening orders for GPRO: 0
# Number of unpaired opening orders for GPRO: 0
#
# --- Analysis for GTLB ---
#
# Analyzing unpaired order 1:
# Open: 2024-03-04 18:04:16.00 - Exp: 2024-03-08 - 73.0/72.0 - short_put_spread - Quantity: 2.0
# Potential closing orders for individual legs:
#   Close: 2024-03-06 14:34:36.19 - Exp: 2024-03-08 - 62.0/61.0 - short_put_spread - Quantity: 4.0
#
# Total quantity of unpaired opening orders for GTLB: 2.0
# Number of unpaired opening orders for GTLB: 1
#
# --- Analysis for HAS ---
#
# Total quantity of unpaired opening orders for HAS: 0
# Number of unpaired opening orders for HAS: 0
#
# --- Analysis for HON ---
#
# Total quantity of unpaired opening orders for HON: 0
# Number of unpaired opening orders for HON: 0
#
# --- Analysis for HOOD ---
#
# Total quantity of unpaired opening orders for HOOD: 0
# Number of unpaired opening orders for HOOD: 0
#
# --- Analysis for IBM ---
#
# Total quantity of unpaired opening orders for IBM: 0
# Number of unpaired opening orders for IBM: 0
#
# --- Analysis for INTC ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-26 16:44:43.43 - Exp: 2023-12-29 - 50.0/50.0 - call_calendar_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2023-12-29 20:30:55.99 - Exp: 2023-12-29 - 50.0 - short_call - Quantity: 1.0
#   Close: 2023-12-28 14:36:19.89 - Exp: 2023-12-29 - 52.0 - long_call - Quantity: 1.0
#
# Total quantity of unpaired opening orders for INTC: 1.0
# Number of unpaired opening orders for INTC: 1
#
# --- Analysis for IWM ---
#
# Total quantity of unpaired opening orders for IWM: 0
# Number of unpaired opening orders for IWM: 0
#
# --- Analysis for JBLU ---
#
# Total quantity of unpaired opening orders for JBLU: 0
# Number of unpaired opening orders for JBLU: 0
#
# --- Analysis for JNUG ---
#
# Total quantity of unpaired opening orders for JNUG: 0
# Number of unpaired opening orders for JNUG: 0
#
# --- Analysis for JPM ---
#
# Total quantity of unpaired opening orders for JPM: 0
# Number of unpaired opening orders for JPM: 0
#
# --- Analysis for KO ---
#
# Total quantity of unpaired opening orders for KO: 0
# Number of unpaired opening orders for KO: 0
#
# --- Analysis for MDB ---
#
# Total quantity of unpaired opening orders for MDB: 0
# Number of unpaired opening orders for MDB: 0
#
# --- Analysis for MDT ---
#
# Total quantity of unpaired opening orders for MDT: 0
# Number of unpaired opening orders for MDT: 0
#
# --- Analysis for META ---
#
# Total quantity of unpaired opening orders for META: 0
# Number of unpaired opening orders for META: 0
#
# --- Analysis for MSFT ---
#
# Total quantity of unpaired opening orders for MSFT: 0
# Number of unpaired opening orders for MSFT: 0
#
# --- Analysis for MU ---
#
# Analyzing unpaired order 1:
# Open: 2019-04-30 06:26:35.36 - Exp: 2019-05-10 - 45.5/44.0 - long_call_spread - Quantity: 2.0
# No potential closing orders found for individual legs.
#
# Analyzing unpaired order 2:
# Open: 2024-04-04 13:50:04.89 - Exp: 2024-04-05 - 130.0/129.0 - short_call_spread - Quantity: 10.0
# Potential closing orders for individual legs:
#   Close: 2024-04-01 13:35:15.95 - Exp: 2024-04-05 - 116.0/114.0 - short_put_spread - Quantity: 5.0
#   Close: 2024-04-04 13:52:59.99 - Exp: 2024-04-05 - 129.0 - short_call - Quantity: 10.0
#   Close: 2024-04-04 13:59:02.88 - Exp: 2024-04-05 - 130.0 - long_call - Quantity: 10.0
#
# Total quantity of unpaired opening orders for MU: 12.0
# Number of unpaired opening orders for MU: 2
#
# --- Analysis for NDAQ ---
#
# Total quantity of unpaired opening orders for NDAQ: 0
# Number of unpaired opening orders for NDAQ: 0
#
# --- Analysis for NFLX ---
#
# Total quantity of unpaired opening orders for NFLX: 0
# Number of unpaired opening orders for NFLX: 0
#
# --- Analysis for NUGT ---
#
# Analyzing unpaired order 1:
# Open: 2024-04-15 18:08:55.05 - Exp: 2024-04-19 - 44.5/44.0 - short_put_spread - Quantity: 10.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for NUGT: 10.0
# Number of unpaired opening orders for NUGT: 1
#
# --- Analysis for NVDA ---
#
# Analyzing unpaired order 1:
# Open: 2024-04-04 14:35:47.25 - Exp: 2024-04-05 - 890.0/887.5 - short_put_spread - Quantity: 10.0
# Potential closing orders for individual legs:
#   Close: 2024-04-01 13:42:04.64 - Exp: 2024-04-05 - 870.0/860.0 - short_put_spread - Quantity: 1.0
#   Close: 2024-04-01 13:41:14.57 - Exp: 2024-04-05 - 877.5/875.0 - short_put_spread - Quantity: 3.0
#   Close: 2024-04-05 19:30:44.37 - Exp: 2024-04-05 - 890.0/885.0 - short_put_spread - Quantity: 3.0
#   Close: 2024-03-22 17:56:59.39 - Exp: 2024-04-05 - 960.0/950.0 - short_call_spread - Quantity: 2.0
#
# Analyzing unpaired order 2:
# Open: 2024-03-27 13:51:31.84 - Exp: 2024-04-05 - 900.0/897.5 - short_put_spread - Quantity: 10.0
# Potential closing orders for individual legs:
#   Close: 2024-04-01 13:42:04.64 - Exp: 2024-04-05 - 870.0/860.0 - short_put_spread - Quantity: 1.0
#   Close: 2024-04-01 13:41:14.57 - Exp: 2024-04-05 - 877.5/875.0 - short_put_spread - Quantity: 3.0
#   Close: 2024-04-05 19:30:44.37 - Exp: 2024-04-05 - 890.0/885.0 - short_put_spread - Quantity: 3.0
#   Close: 2024-03-22 17:56:59.39 - Exp: 2024-04-05 - 960.0/950.0 - short_call_spread - Quantity: 2.0
#
# Total quantity of unpaired opening orders for NVDA: 20.0
# Number of unpaired opening orders for NVDA: 2
#
# --- Analysis for NVDL ---
#
# Analyzing unpaired order 1:
# Open: 2024-08-19 17:05:38.41 - Exp: 2024-08-23 - 68.0/67.5 - long_call_spread - Quantity: 2.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for NVDL: 2.0
# Number of unpaired opening orders for NVDL: 1
#
# --- Analysis for ORCL ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-12 15:17:24.30 - Exp: 2023-12-29 - 103.0/103.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for ORCL: 1.0
# Number of unpaired opening orders for ORCL: 1
#
# --- Analysis for PANW ---
#
# Total quantity of unpaired opening orders for PANW: 0
# Number of unpaired opening orders for PANW: 0
#
# --- Analysis for PFE ---
#
# Total quantity of unpaired opening orders for PFE: 0
# Number of unpaired opening orders for PFE: 0
#
# --- Analysis for PLL ---
#
# Total quantity of unpaired opening orders for PLL: 0
# Number of unpaired opening orders for PLL: 0
#
# --- Analysis for PLTR ---
#
# Total quantity of unpaired opening orders for PLTR: 0
# Number of unpaired opening orders for PLTR: 0
#
# --- Analysis for QCOM ---
#
# Total quantity of unpaired opening orders for QCOM: 0
# Number of unpaired opening orders for QCOM: 0
#
# --- Analysis for QQQ ---
#
# Analyzing unpaired order 1:
# Open: 2019-12-06 11:31:18.79 - Exp: 2019-12-13 - 207.0/205.5/200.0/199.0 - iron_condor - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2019-12-13 20:04:17.30 - Exp: 2019-12-13 - 207.0/205.5 - short_call_spread - Quantity: 1.0
#
# Total quantity of unpaired opening orders for QQQ: 1.0
# Number of unpaired opening orders for QQQ: 1
#
# --- Analysis for RIOT ---
#
# Total quantity of unpaired opening orders for RIOT: 0
# Number of unpaired opening orders for RIOT: 0
#
# --- Analysis for RIVN ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-18 20:05:24.60 - Exp: 2023-12-22 - 24.5/24.5 - call_calendar_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2023-12-19 15:54:04.99 - Exp: 2023-12-22 - 19.0 - long_put - Quantity: 1.0
#
# Total quantity of unpaired opening orders for RIVN: 1.0
# Number of unpaired opening orders for RIVN: 1
#
# --- Analysis for ROKU ---
#
# Total quantity of unpaired opening orders for ROKU: 0
# Number of unpaired opening orders for ROKU: 0
#
# --- Analysis for RTX ---
#
# Total quantity of unpaired opening orders for RTX: 0
# Number of unpaired opening orders for RTX: 0
#
# --- Analysis for SCHH ---
#
# Total quantity of unpaired opening orders for SCHH: 0
# Number of unpaired opening orders for SCHH: 0
#
# --- Analysis for SCHW ---
#
# Total quantity of unpaired opening orders for SCHW: 0
# Number of unpaired opening orders for SCHW: 0
#
# --- Analysis for SHOP ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-21 19:08:06.45 - Exp: 2023-12-22 - 80.0/80.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for SHOP: 1.0
# Number of unpaired opening orders for SHOP: 1
#
# --- Analysis for SIRI ---
#
# Total quantity of unpaired opening orders for SIRI: 0
# Number of unpaired opening orders for SIRI: 0
#
# --- Analysis for SMCI ---
#
# Total quantity of unpaired opening orders for SMCI: 0
# Number of unpaired opening orders for SMCI: 0
#
# --- Analysis for SMH ---
#
# Analyzing unpaired order 1:
# Open: 2024-08-20 13:00:44.93 - Exp: 2024-08-23 - 250.0/247.5 - short_put_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for SMH: 1.0
# Number of unpaired opening orders for SMH: 1
#
# --- Analysis for SNAP ---
#
# Total quantity of unpaired opening orders for SNAP: 0
# Number of unpaired opening orders for SNAP: 0
#
# --- Analysis for SPOT ---
#
# Analyzing unpaired order 1:
# Open: 2024-02-02 16:49:37.07 - Exp: 2024-02-16 - 235.0/235.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Analyzing unpaired order 2:
# Open: 2024-04-17 16:33:44.60 - Exp: 2024-04-19 - 300.0/297.5 - short_call_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for SPOT: 2.0
# Number of unpaired opening orders for SPOT: 2
#
# --- Analysis for SPY ---
#
# Total quantity of unpaired opening orders for SPY: 0
# Number of unpaired opening orders for SPY: 0
#
# --- Analysis for SPYG ---
#
# Total quantity of unpaired opening orders for SPYG: 0
# Number of unpaired opening orders for SPYG: 0
#
# --- Analysis for TSLA ---
#
# Analyzing unpaired order 1:
# Open: 2019-04-26 16:26:02.40 - Exp: 2019-05-03 - 242.5/237.5 - short_call_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2019-04-26 16:54:09.16 - Exp: 2019-05-03 - 237.5 - short_call - Quantity: 1.0
#   Close: 2019-04-26 17:24:56.99 - Exp: 2019-05-03 - 242.5 - long_call - Quantity: 1.0
#
# Analyzing unpaired order 2:
# Open: 2024-03-04 14:58:22.14 - Exp: 2024-03-08 - 195.0/190.0 - short_put_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2024-03-01 18:29:23.82 - Exp: 2024-03-08 - 197.5/195.0 - short_put_spread - Quantity: 5.0
#
# Analyzing unpaired order 3:
# Open: 2024-03-01 19:48:08.25 - Exp: 2024-03-08 - 200.0/197.5 - long_call_spread - Quantity: 5.0
# Potential closing orders for individual legs:
#   Close: 2024-03-01 18:29:23.82 - Exp: 2024-03-08 - 197.5/195.0 - short_put_spread - Quantity: 5.0
#
# Analyzing unpaired order 4:
# Open: 2024-03-01 19:51:10.95 - Exp: 2024-03-08 - 202.5/200.0 - short_put_spread - Quantity: 1.0
# Potential closing orders for individual legs:
#   Close: 2024-03-01 18:29:23.82 - Exp: 2024-03-08 - 197.5/195.0 - short_put_spread - Quantity: 5.0
#
# Total quantity of unpaired opening orders for TSLA: 8.0
# Number of unpaired opening orders for TSLA: 4
#
# --- Analysis for TSM ---
#
# Analyzing unpaired order 1:
# Open: 2024-02-15 15:11:21.07 - Exp: 2024-02-16 - 130.0/130.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for TSM: 1.0
# Number of unpaired opening orders for TSM: 1
#
# --- Analysis for TWTR ---
#
# Analyzing unpaired order 1:
# Open: 2019-04-23 15:51:00.62 - Exp: 2019-09-20 - 37.0/33.0 - short_put_spread - Quantity: 2.0
# Potential closing orders for individual legs:
#   Close: 2019-04-26 06:35:06.62 - Exp: 2019-09-20 - 33.0 - long_put - Quantity: 2.0
#   Close: 2019-05-09 06:58:06.74 - Exp: 2019-09-20 - 36.0/32.0 - short_put_spread - Quantity: 2.0
#   Close: 2019-04-24 19:14:30.49 - Exp: 2019-09-20 - 37.0 - short_put - Quantity: 2.0
#
# Total quantity of unpaired opening orders for TWTR: 2.0
# Number of unpaired opening orders for TWTR: 1
#
# --- Analysis for TXN ---
#
# Total quantity of unpaired opening orders for TXN: 0
# Number of unpaired opening orders for TXN: 0
#
# --- Analysis for UAL ---
#
# Total quantity of unpaired opening orders for UAL: 0
# Number of unpaired opening orders for UAL: 0
#
# --- Analysis for UBER ---
#
# Total quantity of unpaired opening orders for UBER: 0
# Number of unpaired opening orders for UBER: 0
#
# --- Analysis for ULTY ---
#
# Total quantity of unpaired opening orders for ULTY: 0
# Number of unpaired opening orders for ULTY: 0
#
# --- Analysis for USL ---
#
# Total quantity of unpaired opening orders for USL: 0
# Number of unpaired opening orders for USL: 0
#
# --- Analysis for USO ---
#
# Total quantity of unpaired opening orders for USO: 0
# Number of unpaired opening orders for USO: 0
#
# --- Analysis for UVXY ---
#
# Total quantity of unpaired opening orders for UVXY: 0
# Number of unpaired opening orders for UVXY: 0
#
# --- Analysis for VBR ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-26 16:52:32.99 - Exp: 2024-01-19 - 180.0/180.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for VBR: 1.0
# Number of unpaired opening orders for VBR: 1
#
# --- Analysis for VXX ---
#
# Analyzing unpaired order 1:
# Open: 2023-12-19 14:53:36.34 - Exp: 2023-12-22 - 17.0/17.0 - call_calendar_spread - Quantity: 1.0
# No potential closing orders found for individual legs.
#
# Total quantity of unpaired opening orders for VXX: 1.0
# Number of unpaired opening orders for VXX: 1
#
# --- Analysis for WDC ---
#
# Total quantity of unpaired opening orders for WDC: 0
# Number of unpaired opening orders for WDC: 0
#
# --- Analysis for WFC ---
#
# Total quantity of unpaired opening orders for WFC: 0
# Number of unpaired opening orders for WFC: 0
#
# --- Analysis for YEXT ---
#
# Total quantity of unpaired opening orders for YEXT: 0
# Number of unpaired opening orders for YEXT: 0

# %%
# ... existing code ...
import pandas as pd
import json  # Use json to parse the string representation of lists/dictionaries

# Fetch events for TSLA
events = r.get_events('NVDA')

# Convert the events to a DataFrame
events_df = pd.DataFrame(events)

# Select only the desired columns
events_df = events_df[['created_at', 'direction', 'quantity', 'total_cash_amount', 'type']]

# Initialize total cash amount
total_cash_amount = 0

# Sum total_cash_amount based on direction
for _, event in events_df.iterrows():
    if event['direction'] == 'debit':
        total_cash_amount -= float(event['total_cash_amount'])  # Subtract for debit
    elif event['direction'] == 'credit':
        total_cash_amount += float(event['total_cash_amount'])  # Add for credit

# Print the total cash amount
print(f"Total cash amount: {total_cash_amount}")

print(events_df)
# Out:
# Total cash amount: -5014.619999999995
#                     created_at direction quantity total_cash_amount  \
# 0  2024-04-05T20:19:14.102872Z     debit  10.0000         890000.00
# 1  2024-04-05T20:19:13.997059Z     debit  10.0000         900000.00
# 2  2024-04-05T20:19:13.836079Z    credit  10.0000         897492.65
# 3  2024-04-05T20:19:13.674223Z    credit  10.0000         887492.73
#
#          type
# 0  assignment
# 1  assignment
# 2    exercise
# 3    exercise

# %%
# ... existing code ...
import pandas as pd
import json  # Use json to parse the string representation of lists/dictionaries

unique_symbols = aggregated_df['chain_symbol'].unique()
total_option_event_cost = 0  # Initialize total cash amount

# Create a list to store event data
event_data = []

for symbol in unique_symbols:
    events = r.get_events(symbol)  # Fetch events for the symbol
    for event in events:
        # Ignore rows with total_cash_amount = 0
        if float(event['total_cash_amount']) == 0 :
            continue
        
        # Append event details to the list
        event_data.append({
            'created_at': event['created_at'],
            'chain_symbol': symbol,
            'direction': event['direction'],
            'quantity': event['quantity'],
            'total_cash_amount': event['total_cash_amount'],
            'state': event['state'],
            'underlying_price': event['underlying_price']
        })
        if event['direction'] == 'credit':
            total_option_event_cost += float(event['total_cash_amount'])  # Add for exercise
        elif event['direction'] == 'debit':
            total_option_event_cost -= float(event['total_cash_amount'])  # Subtract for assignment

# Create a DataFrame from the event data
events_df = pd.DataFrame(event_data)

# Save the events DataFrame to a new CSV file
events_df.to_csv('../output/option_events.csv', index=True)


# Print the total cash amount
print(f"Total cash amount: {total_option_event_cost}")
# Out:
# Total cash amount: -9115.660000000164

# %%
total =  total_option_cost + total_stock_cost + total_crypto_cost + abs(total_option_event_cost)
print(total)
# Out:
# 8919.601299630365
